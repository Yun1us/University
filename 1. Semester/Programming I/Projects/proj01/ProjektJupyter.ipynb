# %%
def make_sentiment(value):
    """Return a sentiment, which represents a value that may not exist.

    >>> s = make_sentiment(0.2)
    >>> t = make_sentiment(None)
    >>> has_sentiment(s)
    True
    >>> has_sentiment(t)
    False
    >>> sentiment_value(s)
    0.2
    """
    assert value is None or (value >= -1 and value <= 1), 'Illegal value'
    "*** YOUR CODE HERE ***"
    

    return 



def has_sentiment(s):
    """Return whether sentiment s has a value."""
    "*** YOUR CODE HERE ***"
    

import doctest
doctest.testmod()
# Out:
# **********************************************************************
# File "__main__", line 6, in __main__.make_sentiment
# Failed example:
#     has_sentiment(s)
# Expected:
#     True
# Got nothing
# **********************************************************************
# File "__main__", line 8, in __main__.make_sentiment
# Failed example:
#     has_sentiment(t)
# Expected:
#     False
# Got nothing
# **********************************************************************
# File "__main__", line 10, in __main__.make_sentiment
# Failed example:
#     sentiment_value(s)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_sentiment[4]>", line 1, in <module>
#         sentiment_value(s)
#     NameError: name 'sentiment_value' is not defined
# **********************************************************************
# 1 items had failures:
#    3 of   5 in __main__.make_sentiment
# ***Test Failed*** 3 failures.
# TestResults(failed=3, attempted=5)

# %%
from string import ascii_letters

def extract_words(text):
    """Return the words in a tweet, not including punctuation.

    >>> extract_words('anything else.....not my job')
    ['anything', 'else', 'not', 'my', 'job']
    >>> extract_words('i love my job. #winning')
    ['i', 'love', 'my', 'job', 'winning']
    >>> extract_words('make justin # 1 by tweeting #vma #justinbieber :)')
    ['make', 'justin', 'by', 'tweeting', 'vma', 'justinbieber']
    >>> extract_words("paperclips! they're so awesome, cool, & useful!")
    ['paperclips', 'they', 're', 'so', 'awesome', 'cool', 'useful']
    """
    "*** YOUR CODE HERE ***"
    new_string = ""
    # Replace
    for char in text:
       
        if char in ascii_letters:
            new_string += char      
        else: 
            new_string += " "
    return new_string.split()

import doctest
doctest.testmod()
# Out:
# **********************************************************************
# File "__main__", line 6, in __main__.extract_words
# Failed example:
#     extract_words('anything else.....not my job')
# Expected:
#     ['anything', 'else', 'not', 'my', 'job']
# Got:
#     'anything else     not my job'
# **********************************************************************
# File "__main__", line 8, in __main__.extract_words
# Failed example:
#     extract_words('i love my job. #winning')
# Expected:
#     ['i', 'love', 'my', 'job', 'winning']
# Got:
#     'i love my job   winning'
# **********************************************************************
# File "__main__", line 10, in __main__.extract_words
# Failed example:
#     extract_words('make justin # 1 by tweeting #vma #justinbieber :)')
# Expected:
#     ['make', 'justin', 'by', 'tweeting', 'vma', 'justinbieber']
# Got:
#     'make justin     by tweeting  vma  justinbieber   '
# **********************************************************************
# File "__main__", line 12, in __main__.extract_words
# Failed example:
#     extract_words("paperclips! they're so awesome, cool, & useful!")
# Expected:
#     ['paperclips', 'they', 're', 'so', 'awesome', 'cool', 'useful']
# Got:
#     'paperclips  they re so awesome  cool    useful '
# **********************************************************************
# File "__main__", line 9, in __main__.make_tweet
# Failed example:
#     t = make_tweet("just ate lunch", datetime(2012, 9, 24, 13), 38, 74)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_tweet[0]>", line 1, in <module>
#         t = make_tweet("just ate lunch", datetime(2012, 9, 24, 13), 38, 74)
#     NameError: name 'datetime' is not defined
# **********************************************************************
# File "__main__", line 10, in __main__.make_tweet
# Failed example:
#     tweet_words(t)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_tweet[1]>", line 1, in <module>
#         tweet_words(t)
#     NameError: name 't' is not defined
# **********************************************************************
# File "__main__", line 12, in __main__.make_tweet
# Failed example:
#     tweet_time(t)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_tweet[2]>", line 1, in <module>
#         tweet_time(t)
#     NameError: name 'tweet_time' is not defined
# **********************************************************************
# File "__main__", line 14, in __main__.make_tweet
# Failed example:
#     p = tweet_location(t)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_tweet[3]>", line 1, in <module>
#         p = tweet_location(t)
#     NameError: name 'tweet_location' is not defined
# **********************************************************************
# File "__main__", line 15, in __main__.make_tweet
# Failed example:
#     latitude(p)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_tweet[4]>", line 1, in <module>
#         latitude(p)
#     NameError: name 'latitude' is not defined
# **********************************************************************
# 2 items had failures:
#    4 of   4 in __main__.extract_words
#    5 of   5 in __main__.make_tweet
# ***Test Failed*** 9 failures.
# TestResults(failed=9, attempted=9)

# %%
from data import word_sentiments, load_tweets
def sentiment_value(s):
    """Return the value of a sentiment s."""
    assert has_sentiment(s), 'No sentiment value'
    "*** YOUR CODE HERE ***"
    return s 

def make_tweet(text, time, lat, lon):
    """Return a tweet, represented as a python dictionary.

    text      -- A string; the text of the tweet, all in lowercase
    time      -- A datetime object; the time that the tweet was posted
    latitude  -- A number; the latitude of the tweet's location
    longitude -- A number; the longitude of the tweet's location

    >>> t = make_tweet("just ate lunch", datetime(2012, 9, 24, 13), 38, 74)
    >>> tweet_words(t)
    ['just', 'ate', 'lunch']
    >>> tweet_time(t)
    datetime.datetime(2012, 9, 24, 13, 0)
    >>> p = tweet_location(t)
    >>> latitude(p)
    38
    """
    return {'text': text, 'time': time, 'latitude': lat, 'longitude': lon}

def tweet_words(tweet): #tweet is a dictionary from make_tweet
    """Return a list of the words in the text of a tweet."""
    "*** YOUR CODE HERE ***"
    return extract_words(tweet["text"])


def get_word_sentiment(word):
    """Return a sentiment representing the degree of positive or negative
    feeling in the given word, if word is not in the sentiment dictionary.

    >>> sentiment_value(get_word_sentiment('good'))
    0.875
    >>> sentiment_value(get_word_sentiment('bad'))
    -0.625
    >>> sentiment_value(get_word_sentiment('winning'))
    0.5
    >>> has_sentiment(get_word_sentiment('Berkeley'))
    False
    """
    return make_sentiment(word_sentiments.get(word, None))

def analyze_tweet_sentiment(tweet):
    """ Return a sentiment representing the degree of positive or negative
    sentiment in the given tweet, averaging over all the words in the tweet
    that have a sentiment value.

    If no words in the tweet have a sentiment value, return
    make_sentiment(None).

    >>> positive = make_tweet('i love my job. #winning', None, 0, 0)
    >>> round(sentiment_value(analyze_tweet_sentiment(positive)), 5)
    0.29167
    >>> negative = make_tweet("Thinking, 'I hate my job'", None, 0, 0)
    >>> sentiment_value(analyze_tweet_sentiment(negative))
    -0.25
    >>> no_sentiment = make_tweet("Go bears!", None, 0, 0)
    >>> has_sentiment(analyze_tweet_sentiment(no_sentiment))
    False
    """
    average = make_sentiment(None)
    "*** YOUR CODE HERE ***"
    for word in tweet["text"]:
        get_word_sentiment(word)

import doctest
doctest.testmod()
# Out:
# **********************************************************************
# File "__main__", line 57, in __main__.analyze_tweet_sentiment
# Failed example:
#     round(sentiment_value(analyze_tweet_sentiment(positive)), 5)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.analyze_tweet_sentiment[1]>", line 1, in <module>
#         round(sentiment_value(analyze_tweet_sentiment(positive)), 5)
#       File "/tmp/ipykernel_716/582148142.py", line 66, in analyze_tweet_sentiment
#         average = make_sentiment(None)
#     NameError: name 'make_sentiment' is not defined
# **********************************************************************
# File "__main__", line 60, in __main__.analyze_tweet_sentiment
# Failed example:
#     sentiment_value(analyze_tweet_sentiment(negative))
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.analyze_tweet_sentiment[3]>", line 1, in <module>
#         sentiment_value(analyze_tweet_sentiment(negative))
#       File "/tmp/ipykernel_716/582148142.py", line 66, in analyze_tweet_sentiment
#         average = make_sentiment(None)
#     NameError: name 'make_sentiment' is not defined
# **********************************************************************
# File "__main__", line 63, in __main__.analyze_tweet_sentiment
# Failed example:
#     has_sentiment(analyze_tweet_sentiment(no_sentiment))
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.analyze_tweet_sentiment[5]>", line 1, in <module>
#         has_sentiment(analyze_tweet_sentiment(no_sentiment))
#     NameError: name 'has_sentiment' is not defined
# **********************************************************************
# File "__main__", line 37, in __main__.get_word_sentiment
# Failed example:
#     sentiment_value(get_word_sentiment('good'))
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.get_word_sentiment[0]>", line 1, in <module>
#         sentiment_value(get_word_sentiment('good'))
#       File "/tmp/ipykernel_716/582148142.py", line 46, in get_word_sentiment
#         return make_sentiment(word_sentiments.get(word, None))
#     NameError: name 'make_sentiment' is not defined
# **********************************************************************
# File "__main__", line 39, in __main__.get_word_sentiment
# Failed example:
#     sentiment_value(get_word_sentiment('bad'))
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.get_word_sentiment[1]>", line 1, in <module>
#         sentiment_value(get_word_sentiment('bad'))
#       File "/tmp/ipykernel_716/582148142.py", line 46, in get_word_sentiment
#         return make_sentiment(word_sentiments.get(word, None))
#     NameError: name 'make_sentiment' is not defined
# **********************************************************************
# File "__main__", line 41, in __main__.get_word_sentiment
# Failed example:
#     sentiment_value(get_word_sentiment('winning'))
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.get_word_sentiment[2]>", line 1, in <module>
#         sentiment_value(get_word_sentiment('winning'))
#       File "/tmp/ipykernel_716/582148142.py", line 46, in get_word_sentiment
#         return make_sentiment(word_sentiments.get(word, None))
#     NameError: name 'make_sentiment' is not defined
# **********************************************************************
# File "__main__", line 43, in __main__.get_word_sentiment
# Failed example:
#     has_sentiment(get_word_sentiment('Berkeley'))
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.get_word_sentiment[3]>", line 1, in <module>
#         has_sentiment(get_word_sentiment('Berkeley'))
#     NameError: name 'has_sentiment' is not defined
# **********************************************************************
# File "__main__", line 16, in __main__.make_tweet
# Failed example:
#     t = make_tweet("just ate lunch", datetime(2012, 9, 24, 13), 38, 74)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_tweet[0]>", line 1, in <module>
#         t = make_tweet("just ate lunch", datetime(2012, 9, 24, 13), 38, 74)
#     NameError: name 'datetime' is not defined
# **********************************************************************
# File "__main__", line 17, in __main__.make_tweet
# Failed example:
#     tweet_words(t)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_tweet[1]>", line 1, in <module>
#         tweet_words(t)
#     NameError: name 't' is not defined
# **********************************************************************
# File "__main__", line 19, in __main__.make_tweet
# Failed example:
#     tweet_time(t)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_tweet[2]>", line 1, in <module>
#         tweet_time(t)
#     NameError: name 'tweet_time' is not defined
# **********************************************************************
# File "__main__", line 21, in __main__.make_tweet
# Failed example:
#     p = tweet_location(t)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_tweet[3]>", line 1, in <module>
#         p = tweet_location(t)
#     NameError: name 'tweet_location' is not defined
# **********************************************************************
# File "__main__", line 22, in __main__.make_tweet
# Failed example:
#     latitude(p)
# Exception raised:
#     Traceback (most recent call last):
#       File "/usr/lib/python3.10/doctest.py", line 1350, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest __main__.make_tweet[4]>", line 1, in <module>
#         latitude(p)
#     NameError: name 'latitude' is not defined
# **********************************************************************
# 3 items had failures:
#    3 of   6 in __main__.analyze_tweet_sentiment
#    4 of   4 in __main__.get_word_sentiment
#    5 of   5 in __main__.make_tweet
# ***Test Failed*** 12 failures.
# TestResults(failed=12, attempted=15)

# %%
square = lambda x: x ** x 
square(3)
# Out:
# 27

# %%
def sum_digits(x):
    if x < 10:
        return x
    else:
        all_but_the_last = x // 10
        last = x % 10 
        return sum_digits(all_but_the_last) + last

sum_digits(1231312)
# Out:
# 13

# %%
1231312 // 10
1231312 % 10
# Out:
# 2
